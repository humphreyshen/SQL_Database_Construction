# %%
import pandas as pd
import numpy as np

city_original=pd.read_csv("/Users/humphreyshen/Desktop/2021 Database Project/數據預處理/dDt_alumnidb_city.csv")
city_format=pd.DataFrame(city_original)
# Out:
#          1   TW    A    台北市
# 0      NaN  NaN  NaN    NaN
# 1      2.0   TW    B    台中市
# 2      NaN  NaN  NaN    NaN
# 3      3.0   TW    C    基隆市
# 4      NaN  NaN  NaN    NaN
# ..     ...  ...  ...    ...
# 195  102.0   US   WV  西維吉尼亞
# 196    NaN  NaN  NaN    NaN
# 197  103.0   US   WI   威斯康辛
# 198    NaN  NaN  NaN    NaN
# 199  104.0   US   WY    懷俄明
#
# [200 rows x 4 columns]

# %%
import pandas as pd
import numpy as np

city_original=pd.read_csv("/Users/humphreyshen/Desktop/2021 Database Project/數據預處理/dDt_alumnidb_city.csv")
city_format=pd.DataFrame(city_original)
city_withoutblank=city_format.dropna()
city_withoutblank.to_csv("city_withoutblank.csv")

# %%
import pandas as pd
import numpy as np

city=pd.read_csv("/Users/humphreyshen/Desktop/2021 Database Project/數據預處理/city_withoutblank.csv")
city_format=pd.DataFrame(city)
city_nospace=city_format.replace(' ','')
city_nospace.to_csv("city_nospace.csv")
city_nospace
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/bk/ms4pdg4d5tvglvf4crb9f83h0000gn/T/ipykernel_9969/1563476729.py in <module>
#       2 import numpy as np
#       3
# ----> 4 city=pd.read_csv("/Users/humphreyshen/Desktop/2021 Database Project/數據預處理/city_withoutblank.csv")
#       5 city_format=pd.DataFrame(city)
#       6 city_nospace=city_format.replace(' ','')
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
import pandas as pd
import numpy as np

city=pd.read_csv("/Users/humphreyshen/Desktop/2021 Database Project/數據預處理/city_withoutblank.csv")
city_format=pd.DataFrame(city)
city_nospace=city_format.replace(' ','')薛綸
city_nospace
