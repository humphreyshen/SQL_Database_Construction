# %%
import pandas as pd
import numpy as np

personal_original=pd.read_csv("/Users/humphreyshen/Desktop/2021 Database Project/總表下載數據/df_orginal_withoutblank.csv")
personal=pd.DataFrame(personal_original)
personal.head()
# Out:
# /Users/humphreyshen/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3441: DtypeWarning: Columns (5,7,14) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#    id zh_name en_name  gender   birthday  age                    email  \
# 0   1     殷葦婷     NaN     NaN        NaN  NaN      13816630288@163.con
# 1   2     郭敬子     NaN     1.0        NaN  NaN       jimkuo49@gmail.com
# 2   3     陳仕俍     NaN     NaN        NaN  NaN  gelintex@ms27.hinet.net
# 3   4     郭珈郗     NaN     NaN        NaN  NaN        grcekwk@gmail.com
# 4   5     陸大文     NaN     1.0  1954/5/26  NaN   kathyhung168@gmail.com
#
#   zip_code region county district                  address          cell  \
# 0       20     CN    上海市      NaN  中國大陸上海市長寧區香花橋路38弄7號401室           NaN
# 1      200     TW    基隆市      仁愛區           基隆市仁愛區愛七路53號3樓     918136219
# ...

# %%
import pandas as pd
import numpy as np

personal_original=pd.read_csv("/Users/humphreyshen/Desktop/2021 Database Project/總表下載數據/df_orginal_withoutblank.csv")
personal=pd.DataFrame(personal_original)
personal_nospace=personal.replace(' ','')
personal_nospace.head()
# Out:
# /Users/humphreyshen/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3441: DtypeWarning: Columns (5,7,14) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#    id zh_name en_name  gender   birthday  age                    email  \
# 0   1     殷葦婷     NaN     NaN        NaN  NaN      13816630288@163.con
# 1   2     郭敬子     NaN     1.0        NaN  NaN       jimkuo49@gmail.com
# 2   3     陳仕俍     NaN     NaN        NaN  NaN  gelintex@ms27.hinet.net
# 3   4     郭珈郗     NaN     NaN        NaN  NaN        grcekwk@gmail.com
# 4   5     陸大文     NaN     1.0  1954/5/26  NaN   kathyhung168@gmail.com
#
#   zip_code region county district                  address          cell  \
# 0       20     CN    上海市      NaN  中國大陸上海市長寧區香花橋路38弄7號401室           NaN
# 1      200     TW    基隆市      仁愛區           基隆市仁愛區愛七路53號3樓     918136219
# ...

# %%
import pandas as pd
import numpy as np

personal_original=pd.read_csv("/Users/humphreyshen/Desktop/2021 Database Project/總表下載數據/df_orginal_withoutblank.csv")
personal_format=pd.DataFrame(personal_original)
personal_zhname=personal_format['zh_name'].str.replace(u'\u3000',u'')
personal_format_zhname=pd.DataFrame(personal_zhname)
personal_join=personal_format.join(personal_format_zhname)
personal_join
# Out:
# /Users/humphreyshen/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3441: DtypeWarning: Columns (5,7,14) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/bk/ms4pdg4d5tvglvf4crb9f83h0000gn/T/ipykernel_10892/11433271.py in <module>
#       6 personal_zhname=personal_format['zh_name'].str.replace(u'\u3000',u'')
#       7 personal_format_zhname=pd.DataFrame(personal_zhname)
# ----> 8 personal_join=personal_format.join(personal_format_zhname)
#       9 personal_join
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in join(self, other, on, how, lsuffix, rsuffix, sort)
#    9093         5  K5  A5  NaN
#    9094         """
# -> 9095         return self._join_compat(
# ...

# %%
personal_original_nospace=personal_original.loc['zh_name'].str.replace(u'\u3000',u'')
personal_original_nospace
str.replace(u'\u3000',u'')
